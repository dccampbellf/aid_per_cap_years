# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline

# %%
df_percap=pd.read_csv(r'C:\Users\dccam\Desktop\df_aid_per_capita_filterd_countries.csv')

# %%
df_percap.drop(df_percap.columns[0], axis=1,inplace=True)
df_percap=df_percap[27:]
df_percap.reset_index(drop=True,inplace=True)

# %%
df_percap.rename(columns={'costa rica':'costa_rica','el salvador':'el_salvador','dominican republic':'dominican_republic'},inplace=True)

# %%
df_percap.columns
# Out:
# Index(['year', 'argentina', 'brazil', 'costa_rica', 'dominican_republic',
#        'el_salvador', 'honduras', 'indonesia', 'panama', 'paraguay', 'peru',
#        'thailand', 'uruguay'],
#       dtype='object')

# %%
df_percap.head(3)
# Out:
#    year  argentina  brazil  costa_rica  dominican_republic  el_salvador  \
# 0  1994       4.68    1.63     25.6000                7.63         49.2
# 1  1995       4.25    1.63     13.0000               13.80         49.6
# 2  1996       3.47    1.57     -0.0578               10.40         48.2
#
#    honduras  indonesia  panama  paraguay  peru  thailand  uruguay
# 0      46.1       7.76    14.3      19.4  14.6      9.81     23.4
# 1      65.6       6.36    17.0      25.4  15.9     14.10     21.4
# 2      40.6       5.29    20.7      14.7  13.4     13.80     11.3

# %%
df_percap
plt.figure(figsize=(10,10))
df_percap.set_index('year')[['argentina', 'brazil', 'costa_rica', 'dominican_republic',
       'el_salvador', 'honduras', 'indonesia', 'panama', 'paraguay', 'peru',
       'thailand', 'uruguay']].boxplot(figsize=(5,5));

plt.xticks(rotation = 45)
plt.legend( loc='upper right', fontsize='xx-large');
# Out:
# No handles with labels found to put in legend.

# %%
country=['argentina', 'brazil', 'costa rica', 'dominican republic',
       'el salvador', 'honduras', 'indonesia', 'panama', 'paraguay', 'peru',
       'thailand', 'uruguay']

plt.subplots(figsize=(20,20),sharey=False, squeeze=True)
plt.style.use('fivethirtyeight')

ax1 = plt.subplot(4,3,1)
ax1.plot('year','argentina',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Argentina')

ax1 = plt.subplot(4,3,2)
ax1.plot('year','brazil', data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Brazil')

ax1 = plt.subplot(4,3,3)
ax1.plot('year','costa_rica',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Costa Rica')

ax1 = plt.subplot(4,3,4)
ax1.plot('year','dominican_republic',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Dominican Republic')

ax1 = plt.subplot(4,3,5)
ax1.plot('year','el_salvador',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('El Salvador')

ax1 = plt.subplot(4,3,6)
ax1.plot('year','honduras',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Honduras')

ax1 = plt.subplot(4,3,7)
ax1.plot('year','indonesia',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Indonesia')

ax1 = plt.subplot(4,3,8)
ax1.plot('year','panama',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Panama')

ax1 = plt.subplot(4,3,9)
ax1.plot('year', 'paraguay',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Paraguar')

ax1 = plt.subplot(4,3,10)
ax1.plot('year','peru',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Peru')

ax1 = plt.subplot(4,3,11)
ax1.plot('year','thailand', data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Thailand')

ax1 = plt.subplot(4,3,12)
ax1.plot('year','uruguay',data=df_percap)
ax1.set_xlim([1970, 2020])
ax1.set_ylim([-25, 150])
ax1.set_title('Uruguay')

plt.tight_layout()
plt.tight_layout(pad=3.0)
# Out:
# <ipython-input-11-cb8daed8504e>:63: RuntimeWarning: Second argument 'peru' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   ax1.plot('year','peru',data=df_percap)
